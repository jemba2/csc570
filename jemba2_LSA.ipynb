# %%
from sklearn.datasets import fetch_20newsgroups
categories = ['rec.sport.baseball']
dataset = fetch_20newsgroups(subset='all',shuffle=True, random_state=42, categories=categories)
corpus = dataset.data

# %%
from bs4 import BeautifulSoup
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopset = set(stopwords.words('english'))
stopset.update(['lt','p','/p','br','amp','quot','field','font','normal','span','0px','rgb','style','51', 
                'spacing','text','helvetica','size','family', 'space', 'arial', 'height', 'indent', 'letter',
                'line','none','sans','serif','transform','line','variant','weight','times', 'new','strong', 'video', 'title',
                'white','word','letter', 'roman','0pt','16','color','12','14','21', 'neue', 'apple', 'class', 'nntp', '00',
                'posting', '@', 'edu', 'com', '000', 'cs', 'net', 'from', 'subject', 'organization', 'uiuc', 'morris',
                'tc', 'rose', 'jhunix', 'rose', 'duke', 'hulman', 'hcf', 'cc', 'bob', 'cornell', 'stanford', 'hp', 'ca',
                'netcom', 'williams', 'university', 'ted', 'aix', 'ibm', 'scott', 'roger', 'vb30', 'lafibm', '\n'])

# %%
vectorizer = TfidfVectorizer(stop_words=stopset, use_idf=True, ngram_range=(1, 3))
X = vectorizer.fit_transform(corpus)

# %%
X[0]
# Out:
# <1x186441 sparse matrix of type '<class 'numpy.float64'>'
# 	with 215 stored elements in Compressed Sparse Row format>

# %%
print(X[0])
# Out:
#   (0, 51333)	0.0742541584225
#   (0, 187193)	0.0742541584225
#   (0, 29035)	0.0742541584225
#   (0, 144367)	0.0742541584225
#   (0, 62630)	0.0742541584225
#   (0, 76217)	0.0742541584225
#   (0, 131561)	0.0742541584225
#   (0, 101515)	0.0742541584225
#   (0, 65020)	0.0742541584225
#   (0, 112745)	0.0742541584225
#   (0, 161266)	0.0742541584225
#   (0, 179185)	0.0742541584225
#   (0, 117938)	0.0742541584225
#   (0, 62770)	0.0742541584225
#   (0, 102007)	0.0742541584225
#   (0, 93837)	0.0742541584225
#   (0, 131476)	0.0742541584225
#   (0, 141507)	0.0742541584225
#   (0, 96457)	0.0742541584225
#   (0, 113386)	0.0742541584225
#   (0, 163663)	0.0742541584225
#   (0, 59258)	0.0742541584225
#   (0, 51373)	0.0742541584225
#   (0, 35846)	0.0742541584225
#   (0, 62756)	0.0742541584225
#   :	:
#   (0, 82873)	0.0346001351527
#   (0, 183717)	0.0157169729261
#   (0, 141755)	0.0558001979418
#   (0, 120623)	0.111600395884
#   (0, 37644)	0.100073036534
#   (0, 40876)	0.105674518346
#   (0, 16587)	0.0742541584225
#   (0, 93223)	0.111600395884
#   (0, 25839)	0.0162563292134
#   (0, 99162)	0.0103616461005
#   (0, 161855)	0.0613515123311
#   (0, 47952)	0.0392240312508
#   (0, 173504)	0.0395731952461
#   (0, 112542)	0.0613515123311
#   (0, 173540)	0.0181341230031
#   (0, 156916)	0.0376363792236
#   (0, 29557)	0.0309485514121
#   (0, 120010)	0.0103824949972
#   (0, 66566)	0.125878328717
#   (0, 51255)	0.162637637744
#   (0, 159770)	0.0102993514462
#   (0, 38902)	0.0510673129807
#   (0, 38923)	0.0510673129807
#   (0, 97504)	0.050036518267
#   (0, 184651)	0.0742541584225

# %%
X.shape
# Out:
# (994, 186441)

# %%
lsa = TruncatedSVD(n_components=100, n_iter=100)
lsa.fit(X)
# Out:
# TruncatedSVD(algorithm='randomized', n_components=100, n_iter=100,
#        random_state=None, tol=0.0)

# %%
terms = vectorizer.get_feature_names()
for i, comp in enumerate(lsa.components_): 
    termsInComp = zip (terms,comp)
    sortedTerms =  sorted(termsInComp, key=lambda x: x[1], reverse=True) [:10]
    print("Concept %d:" % i )
    for term in sortedTerms:
        print(term[0])
    print (" ")
# Out:
# Concept 0:
# year
# team
# would
# game
# writes
# article
# baseball
# players
# games
# one
#
# Concept 1:
# jewish
# jewish baseball
# baseball players
# jewish baseball players
# come
# lafayette
# baseball
# players
# play
# lowenstein
#
# Concept 2:
# clutch
# hit
# sabo
# samuel
# performance
# year
# hitter
# situations
# may
# well
#
# Concept 3:
# 03
# 02
# games
# lost
# 04
# really
# hitter
# 05
# 01
# colorado
#
# Concept 4:
# fame
# dave
# sox
# well
# hall
# kingman
# 04
# hall fame
# clutch
# pitcher
#
# Concept 5:
# gant
# hirschbeck
# hall
# bonds
# teams
# two
# hall fame
# kingman
# right
# want
#
# Concept 6:
# anyone
# let
# would
# pitcher
# hall
# game
# players
# hirschbeck
# credit
# gant
#
# Concept 7:
# runs
# time
# anyone
# well
# defensive
# rather
# year
# ball
# 001 100
# last
#
# Concept 8:
# team
# bonds
# best
# series
# lopez
# win
# fan
# performance
# giants
# david
#
# Concept 9:
# alomar
# let
# news
# bad
# look
# go
# mets
# home
# runs
# young
#
# Concept 10:
# year
# smith
# gant
# toronto
# could
# ball
# team
# better
# pitching
# way
#
# Concept 11:
# league
# got
# mail
# believe
# right
# want
# come
# teams
# alomar
# mark
#
# Concept 12:
# might
# could
# play
# game
# david
# pitch
# long
# people
# average
# made
#
# Concept 13:
# david
# lopez
# three
# players
# really
# mark
# stats
# post
# colorado
# jewish
#
# Concept 14:
# last
# games
# year
# like
# season
# start
# asd
# time
# bonds
# division
#
# Concept 15:
# since
# hit
# hitting
# batting
# look
# rickert
# help
# season
# average
# ball
#
# Concept 16:
# team
# year
# season
# also
# 10
# make
# last
# right
# might
# extra
#
# Concept 17:
# would
# bonds
# distribution
# go
# world
# news
# many
# mike
# one
# base
#
# Concept 18:
# runs
# game
# two
# first
# run
# stats
# alomar
# 22
# jewish
# would
#
# Concept 19:
# years
# usa
# season
# cubs
# asd
# since
# fans
# jays
# mets
# distribution
#
# Concept 20:
# alomar
# third
# little
# win
# baseball
# clemens
# year
# hirschbeck
# winning
# red
#
# Concept 21:
# really
# two
# first
# fans
# ever
# second
# sox
# gant
# list
# sabo
#
# Concept 22:
# first
# fan
# 10
# pitch
# also
# even
# may
# series
# know
# great
#
# Concept 23:
# say
# year
# ever
# fan
# division
# would
# never
# behind
# help
# see
#
# Concept 24:
# like
# stats
# get
# second
# sherri
# red
# sherri nichols
# good
# clutch
# help
#
# Concept 25:
# hitter
# also
# mets
# pitching
# good
# first
# like
# third
# run
# could
#
# Concept 26:
# make
# jays
# anyone
# clutch
# giants
# team
# think
# world
# runs
# pitching
#
# Concept 27:
# runs
# baseball
# much
# might
# mark
# know
# day
# 1993
# let
# 1992
#
# Concept 28:
# best
# could
# always
# last
# year
# time
# great
# players
# second
# people
#
# Concept 29:
# mets
# baseball
# probably
# back
# remember
# next
# pitcher
# league
# jewish
# spot
#
# Concept 30:
# blue
# runs
# think
# help
# something
# steve
# like
# fans
# jewish
# mike
#
# Concept 31:
# baseball
# also
# player
# trying
# news
# since
# players
# day
# al
# total
#
# Concept 32:
# runs
# john
# hit
# game
# better
# bonds
# probably
# batting
# two
# back
#
# Concept 33:
# runs
# sox
# distribution
# red
# phillies
# let
# hit
# right
# make
# career
#
# Concept 34:
# play
# base
# league
# know
# back
# stats
# hit
# fans
# season
# 20
#
# Concept 35:
# many
# team
# players
# think
# boston
# like
# much
# michael
# mail
# john
#
# Concept 36:
# know
# see
# would
# bonds
# mike
# 10
# say
# mets
# last
# time
#
# Concept 37:
# runs
# writes article
# seems
# jewish
# three
# 1993
# would
# left
# giants
# league
#
# Concept 38:
# first
# baseball
# could
# many
# good
# year
# sox
# think
# people
# years
#
# Concept 39:
# good
# games
# little
# players
# average
# runs
# ball
# one
# left
# david
#
# Concept 40:
# year
# mike
# back
# every
# make
# let
# said
# way
# jewish
# michael
#
# Concept 41:
# lot
# players
# play
# red
# run
# much
# world
# either
# say
# always
#
# Concept 42:
# season
# pitching
# batting
# know
# john
# lot
# may
# stats
# right
# division
#
# Concept 43:
# player
# team
# three
# bad
# news
# could
# like
# long
# 22
# cubs
#
# Concept 44:
# braves
# good
# many
# pitcher
# defense
# course
# blue
# game
# hr
# al
#
# Concept 45:
# many
# game
# lot
# pitches
# first
# people
# might
# braves
# two
# steve
#
# Concept 46:
# 10
# would
# think
# run
# really
# john
# reply
# something
# better
# play
#
# Concept 47:
# team
# runs
# david
# years
# make
# season
# braves
# well
# around
# ball
#
# Concept 48:
# game
# baseball
# even
# year
# pitcher
# going
# jewish
# sure
# pitches
# long
#
# Concept 49:
# first
# players
# reply
# best
# win
# around
# writes article
# smith
# see
# series
#
# Concept 50:
# back
# anyone
# hit
# two
# baseball
# still
# year
# give
# division
# young
#
# Concept 51:
# go
# take
# better
# day
# get
# reply
# average
# mike
# distribution
# next
#
# Concept 52:
# could
# play
# like
# let
# right
# distribution
# way
# league
# three
# red
#
# Concept 53:
# braves
# much
# hit
# pitching
# also
# right
# baseball
# team
# like
# teams
#
# Concept 54:
# good
# let
# go
# smith
# games
# season
# back
# pitch
# take
# get
#
# Concept 55:
# believe
# go
# many
# think
# hit
# win
# game
# maybe
# big
# next
#
# Concept 56:
# year
# best
# last
# one
# maybe
# get
# believe
# players
# may
# play
#
# Concept 57:
# well
# pitching
# 001 100
# first
# best
# mets
# far
# long
# hitter
# better
#
# Concept 58:
# games
# think
# well
# home
# good
# host
# let
# better
# like
# world
#
# Concept 59:
# hitter
# host
# people
# david
# think
# much
# time
# really
# mark
# could
#
# Concept 60:
# pitcher
# first
# games
# much
# ball
# baseball
# long
# two
# said
# season
#
# Concept 61:
# league
# games
# even
# play
# got
# help
# 000th
# way
# season
# david
#
# Concept 62:
# team
# see
# would
# say
# pitching
# could
# hit
# fans
# hitting
# runs
#
# Concept 63:
# john
# season
# think
# home
# say
# get
# writes
# really
# day
# 000th
#
# Concept 64:
# people
# year
# batting
# time
# world
# hit
# ball
# list
# pitchers
# al
#
# Concept 65:
# players
# also
# game
# league
# dave
# average
# come
# long
# would
# think
#
# Concept 66:
# game
# see
# like
# win
# around
# get
# hit
# well
# hitting
# second
#
# Concept 67:
# player
# first
# league
# back
# hit
# well
# get
# red
# game
# best
#
# Concept 68:
# see
# hit
# left
# know
# really
# well
# last year
# play
# smith
# one
#
# Concept 69:
# even
# year
# game
# first
# one
# people
# usa
# last
# mark
# back
#
# Concept 70:
# day
# back
# season
# like
# pitching
# many
# david
# gant
# distribution
# hitter
#
# Concept 71:
# writes article
# game
# even
# team
# like
# home
# performance
# sox
# nl
# jewish
#
# Concept 72:
# let
# best
# 10
# 001
# sox
# pitching
# time
# better
# stats
# win
#
# Concept 73:
# baseball
# player
# best
# players
# last year
# good
# mets
# games
# writes article
# jack
#
# Concept 74:
# baseball
# first
# make
# never
# like
# right
# know
# much
# also
# player
#
# Concept 75:
# braves
# better
# league
# 10
# know
# teams
# got
# john
# see
# believe
#
# Concept 76:
# good
# could
# last
# team
# game
# season
# get
# ny
# make
# list
#
# Concept 77:
# better
# get
# would
# game
# first
# know
# braves
# might
# point
# games
#
# Concept 78:
# game
# win
# hitter
# 10
# play
# first
# league
# back
# let
# hitting
#
# Concept 79:
# good
# say
# like
# get
# people
# know
# world
# ball
# pitcher
# play
#
# Concept 80:
# baseball
# much
# would
# way
# go
# first
# last
# two
# bad
# know
#
# Concept 81:
# hit
# host
# game
# league
# good
# win
# distribution
# season
# years
# know
#
# Concept 82:
# games
# well
# look
# league
# hit
# say
# first
# like
# back
# ball
#
# Concept 83:
# go
# team
# much
# pitcher
# league
# still
# also
# like
# first
# player
#
# Concept 84:
# would
# think
# one
# could
# host
# distribution
# win
# like
# time
# world
#
# Concept 85:
# one
# good
# would
# dave
# best
# pitching
# run
# believe
# long
# hitting
#
# Concept 86:
# one
# players
# years
# right
# much
# say
# even
# way
# well
# pretty
#
# Concept 87:
# think
# one
# would
# first
# two
# last
# year
# games
# win
# runs
#
# Concept 88:
# game
# team
# like
# really
# host
# could
# 001
# 20
# years
# players
#
# Concept 89:
# think
# could
# team
# see
# last
# article
# ball
# great
# 10
# give
#
# Concept 90:
# runs
# better
# good
# two
# one
# year
# thanks
# really
# team
# never
#
# Concept 91:
# one
# know
# still
# many
# team
# well
# win
# really
# league
# baseball
#
# Concept 92:
# two
# baseball
# team
# good
# may
# even
# host
# 000th
# article
# distribution
#
# Concept 93:
# like
# baseball
# 001
# hitter
# last year
# also
# years
# maybe
# going
# braves
#
# Concept 94:
# would
# better
# well
# let
# host
# really
# pretty
# see
# last year
# even
#
# Concept 95:
# think
# time
# see
# baseball
# last year
# one
# come
# game
# good
# first
#
# Concept 96:
# one
# get
# host
# say
# first
# like
# players
# also
# time
# season
#
# Concept 97:
# last
# time
# host
# years
# 001 100
# world
# last year
# good
# back
# two
#
# Concept 98:
# better
# last
# baseball
# host
# see
# 001
# one
# like
# games
# league
#
# Concept 99:
# writes
# article
# time
# games
# last year
# get
# back
# years
# really
# know

# %%
corpus[40]
# Out:
# "From: dansmith@mcopn2.dseg.ti.com (Danny Smith)\nSubject: Braves win opener\nNntp-Posting-Host: s355.dseg.ti.com\nReply-To: dansmith@mcopn2.dseg.ti.com\nOrganization: Texas Instruments, Inc.\nLines: 15\n\nWell, Maddux looked excellent as the Braves shutout the Cubs 1 - 0.\nJustice drove in the only run with an RBI single in the first. Get\nready for him to have a monster year. He is now hitting the ball to\nthe opposite field with a lot of power to go with his natural \npower to right field and his good batting eye. If he stays healthy\nwhich he should (his back is full strength this year) he should\nget over 100 RBI and close to 30 HR.\n\nIn another note, the Marlins got off to a good start beating the\nDodgers. I believe the score was 6 - 3 but I'm not sure. I wish\nthem and the Rockies well this year. Hell. I think it would be\nfunny to watch the Dodgers hit the cellar again this year.\n\nDan Smith\n\n"
